# %% [markdown]
# # Corrigir Consultas

# %%
''' CORRIGIR CONSULTA  ''' 

import xml.etree.ElementTree as ET
import os

# Obter a lista de nomes de arquivo XML no diretório
diretorio = 'C:/Users/flavio.bueno/Projetos_Python/XML'
arquivos_xml = [arquivo for arquivo in os.listdir(diretorio) if arquivo.endswith('.xml')]


# Processar cada arquivo XML
for arquivo in arquivos_xml:
    # Carregar o arquivo XML
    caminho_arquivo = os.path.join(diretorio, arquivo)
    tree = ET.parse(caminho_arquivo)
    root = tree.getroot()

    # Definir o namespace
    namespace = {'ans': 'http://www.ans.gov.br/padroes/tiss/schemas'}    
    
    # Navegar e fazer alterações no XML
    for elemento in root.findall('.//ans:guiaConsulta', namespace):
        numero_carteira = elemento.find('.//ans:numeroCarteira', namespace)

        # Verificar o número de caracteres
        if len(numero_carteira.text) < 6:
            numero_carteira.text = '00' + numero_carteira.text
        
        elif len(numero_carteira.text) < 7:
            numero_carteira.text = '0' + numero_carteira.text  
    
    # Salvar as alterações de volta no arquivo
    tree.write(caminho_arquivo, encoding='UTF-8', xml_declaration=True)

# %% [markdown]
# # Corrigir SADT

# %%
''' CORRIGIR SADT  ''' 

import xml.etree.ElementTree as ET
import os

# Definir o namespace
namespace = {
    'ans': 'http://www.ans.gov.br/padroes/tiss/schemas',
    'xsi': 'http://www.w3.org/2001/XMLSchema-instance'
}

# Obter a lista de nomes de arquivo XML no diretório
diretorio = 'C:/Users/flavio.bueno/Projetos_Python/XML'
arquivos_xml = [arquivo for arquivo in os.listdir(diretorio) if arquivo.endswith('.xml')]

# Processar cada arquivo XML
for arquivo in arquivos_xml:
    # Carregar o arquivo XML
    caminho_arquivo = os.path.join(diretorio, arquivo)
    tree = ET.parse(caminho_arquivo)
    root = tree.getroot()

    # Navegar e fazer alterações no XML
    for elemento in root.findall('.//ans:guiaSP-SADT', namespace):
        numero_carteira = elemento.find('.//ans:numeroCarteira', namespace)

        # Verificar o número de caracteres
        if len(numero_carteira.text) < 6:
            numero_carteira.text = '00' + numero_carteira.text
            
        elif len(numero_carteira.text) < 7:
            numero_carteira.text = '0' + numero_carteira.text  

    # Salvar as alterações de volta no arquivo
    tree.write(caminho_arquivo, encoding='UTF-8', xml_declaration=True)

# %%
import xml.etree.ElementTree as ET
import os

# Definir o namespace
namespace = {
    'ans': 'http://www.ans.gov.br/padroes/tiss/schemas'
    #'xsi': 'http://www.w3.org/2001/XMLSchema-instance'
}

# Obter a lista de nomes de arquivo XML no diretório
diretorio = 'C:/Users/flavio.bueno/Projetos_Python/XML'
arquivos_xml = [arquivo for arquivo in os.listdir(diretorio) if arquivo.endswith('.xml')]

# Processar cada arquivo XML
for arquivo in arquivos_xml:
    # Carregar o arquivo XML
    caminho_arquivo = os.path.join(diretorio, arquivo)
    tree = ET.parse(caminho_arquivo)
    root = tree.getroot()
    
    
# Encontrar todas as guias SP-SADT
guias_sp_sadt = root.findall('.//ns0:guiaSP-SADT', namespace)

# Iterar sobre as guias SP-SADT
for guia_sp_sadt in guias_sp_sadt:
    valor_total_geral_element = guia_sp_sadt.find('.//ns0:valorTotalGeral', namespace)
    procedimentos_executados_element = guia_sp_sadt.find('.//ns0:procedimentosExecutados', namespace)
    valor_proced_geral_element = guia_sp_sadt.find('.//ns0:valorProcedimentos', namespace)
    
    # Verificar se as tags existem
    if valor_total_geral_element is not None and procedimentos_executados_element is not None:
        valor_total = 0.0
        
        # Encontrar todas as tags <ns0:valorTotal> dentro de <ns0:procedimentosExecutados>
        valor_total_elements = procedimentos_executados_element.findall('.//ns0:valorTotal', namespace)
        
        # Somar os valores
        for valor_total_element in valor_total_elements:
            valor = float(valor_total_element.text) if valor_total_element.text else 0.0
            valor_total += valor
        
        # Substituir o valor de <ns0:valorTotalGeral> pelo valor total calculado formatado com duas casas decimais
        valor_total_geral_element.text = '{:.2f}'.format(valor_total)
        valor_proced_geral_element.text = '{:.2f}'.format(valor_total)
        
    # Salvar as alterações de volta no arquivo
tree.write(caminho_arquivo, encoding='UTF-8', xml_declaration=True)
# Out:
# Traceback (most recent call last):
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\FLAVIO~1.BUE\AppData\Local\Temp/ipykernel_15000/1980961613.py", line 23, in <module>
#     guias_sp_sadt = root.findall('.//ns0:guiaSP-SADT', namespace)
#
#   File "C:\ProgramData\Anaconda3\lib\xml\etree\ElementPath.py", line 395, in findall
#     return list(iterfind(elem, path, namespaces))
#
#   File "C:\ProgramData\Anaconda3\lib\xml\etree\ElementPath.py", line 368, in iterfind
#     selector.append(ops[token[0]](next, token))
#
#   File "C:\ProgramData\Anaconda3\lib\xml\etree\ElementPath.py", line 184, in prepare_descendant
#     token = next()
#
#   File "C:\ProgramData\Anaconda3\lib\xml\etree\ElementPath.py", line 86, in xpath_tokenizer
#     raise SyntaxError("prefix %r not found in prefix map" % prefix) from None
#
#   File "<string>", line unknown
# SyntaxError: prefix 'ns0' not found in prefix map

# %% [markdown]
# # Atualização de valor de procediementos SADT

# %%
from xml.etree import ElementTree as ET

# Carregar o XML em uma árvore
tree = ET.parse('SADT0000004116_26052023616567.xml')
root = tree.getroot()

# Definir o namespace
namespace = {'ns0': 'http://www.ans.gov.br/padroes/tiss/schemas'}


# Encontrar todas as guias SP-SADT
guias_sp_sadt = root.findall('.//ns0:guiaSP-SADT', namespace)

# Iterar sobre as guias SP-SADT
for guia_sp_sadt in guias_sp_sadt:
    valor_total_geral_element = guia_sp_sadt.find('.//ns0:valorTotalGeral', namespace)
    procedimentos_executados_element = guia_sp_sadt.find('.//ns0:procedimentosExecutados', namespace)
    valor_proced_geral_element = guia_sp_sadt.find('.//ns0:valorProcedimentos', namespace)
    
    # Verificar se as tags existem
    if valor_total_geral_element is not None and procedimentos_executados_element is not None:
        valor_total = 0.0
        
        # Encontrar todas as tags <ns0:valorTotal> dentro de <ns0:procedimentosExecutados>
        valor_total_elements = procedimentos_executados_element.findall('.//ns0:valorTotal', namespace)
        
        # Somar os valores
        for valor_total_element in valor_total_elements:
            valor = float(valor_total_element.text) if valor_total_element.text else 0.0
            valor_total += valor
        
        # Substituir o valor de <ns0:valorTotalGeral> pelo valor total calculado formatado com duas casas decimais
        valor_total_geral_element.text = '{:.2f}'.format(valor_total)
        valor_proced_geral_element.text = '{:.2f}'.format(valor_total)
        
# Exibir o XML modificado
#xml_string = ET.tostring(root, encoding='utf-8').decode('utf-8')
#print(xml_string)
# Salvar as alterações de volta no arquivo
tree.write('mod_'+tree, encoding='UTF-8', xml_declaration=True)
# Out:
# <ns0:mensagemTISS xmlns:ns0="http://www.ans.gov.br/padroes/tiss/schemas" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.ans.gov.br/padroes/tiss/schemas http://www.ans.gov.br/padroes/tiss/schemas/tissV3_03_03.xsd">
# <ns0:cabecalho>
# <ns0:identificacaoTransacao>
# <ns0:tipoTransacao>ENVIO_LOTE_GUIAS</ns0:tipoTransacao>
# <ns0:sequencialTransacao>0000004116</ns0:sequencialTransacao>
# <ns0:dataRegistroTransacao>2023-05-26</ns0:dataRegistroTransacao>
# <ns0:horaRegistroTransacao>17:07:36</ns0:horaRegistroTransacao>
# </ns0:identificacaoTransacao>
# <ns0:origem>
# <ns0:identificacaoPrestador>
# <ns0:codigoPrestadorNaOperadora>3733</ns0:codigoPrestadorNaOperadora>
# </ns0:identificacaoPrestador>
# </ns0:origem>
# <ns0:destino>
# <ns0:registroANS>385255</ns0:registroANS>
# </ns0:destino>
# <ns0:Padrao>3.03.03</ns0:Padrao>
# </ns0:cabecalho>
# <ns0:prestadorParaOperadora>
# <ns0:loteGuias>
# <ns0:numeroLote>0000004116</ns0:numeroLote>
# <ns0:guiasTISS>
# <ns0:guiaSP-SADT>
# <ns0:cabecalhoGuia>
# <ns0:registroANS>385255</ns0:registroANS>
# <ns0:numeroGuiaPrestador>528957</ns0:numeroGuiaPrestador>
# <ns0:guiaPrincipal>528957</ns0:guiaPrincipal>
# </ns0:cabecalhoGuia>
# <ns0:dadosBeneficiario>
# <ns0:numeroCarteira>1671405</ns0:numeroCarteira>
# <ns0:atendimentoRN>N</ns0:atendimentoRN>
# <ns0:nomeBeneficiario>ISOLETE GABRICHE</ns0:nomeBeneficiario>
# <ns0:numeroCNS>0</ns0:numeroCNS>
# </ns0:dadosBeneficiario>
# <ns0:dadosSolicitante>
# <ns0:contratadoSolicitante>
# <ns0:codigoPrestadorNaOperadora>3733</ns0:codigoPrestadorNaOperadora>
# <ns0:nomeContratado>CENTRO CLINICO DE DIAGNOSTICOS POR IMAGEM BARTIRA LTDA EPP</ns0:nomeContratado>
# </ns0:contratadoSolicitante>
# <ns0:profissionalSolicitante>
# <ns0:nomeProfissional>MIRNA DA SILVA DE BARROS</ns0:nomeProfissional>
# <ns0:conselhoProfissional>06</ns0:conselhoProfissional>
# <ns0:numeroConselhoProfissional>160746</ns0:numeroConselhoProfissional>
# <ns0:UF>35</ns0:UF>
# <ns0:CBOS>225125</ns0:CBOS>
# </ns0:profissionalSolicitante>
# </ns0:dadosSolicitante>
# <ns0:dadosSolicitacao>
# <ns0:dataSolicitacao>2023-05-11</ns0:dataSolicitacao>
# <ns0:caraterAtendimento>1</ns0:caraterAtendimento>
# </ns0:dadosSolicitacao>
# <ns0:dadosExecutante>
# <ns0:contratadoExecutante>
# <ns0:cnpjContratado>17642803000142</ns0:cnpjContratado>
# <ns0:nomeContratado>UNIHOSP SAUDE S A</ns0:nomeContratado>
# </ns0:contratadoExecutante>
# <ns0:CNES>0000000</ns0:CNES>
# </ns0:dadosExecutante>
# <ns0:dadosAtendimento>
# <ns0:tipoAtendimento>03</ns0:tipoAtendimento>
# <ns0:indicacaoAcidente>9</ns0:indicacaoAcidente>
# <ns0:tipoConsulta>4</ns0:tipoConsulta>
# </ns0:dadosAtendimento>
# <ns0:procedimentosExecutados>
# <ns0:procedimentoExecutado>
# <ns0:dataExecucao>2023-05-11</ns0:dataExecucao>
# <ns0:horaInicial>13:27:00</ns0:horaInicial>
# <ns0:horaFinal>13:27:00</ns0:horaFinal>
# <ns0:procedimento>
# <ns0:codigoTabela>22</ns0:codigoTabela>
# <ns0:codigoProcedimento>31601014</ns0:codigoProcedimento>
# <ns0:descricaoProcedimento>ACUPUNTURA POR SESSAO</ns0:descricaoProcedimento>
# </ns0:procedimento>
# <ns0:quantidadeExecutada>1</ns0:quantidadeExecutada>
# <ns0:reducaoAcrescimo>1.00</ns0:reducaoAcrescimo>
# <ns0:valorUnitario>30.00</ns0:valorUnitario>
# <ns0:valorTotal>30.00</ns0:valorTotal>
# <ns0:equipeSadt>
# <ns0:grauPart>01</ns0:grauPart>
# <ns0:codProfissional>
# <ns0:codigoPrestadorNaOperadora>01</ns0:codigoPrestadorNaOperadora>
# </ns0:codProfissional>
# <ns0:nomeProf>MIRNA DA SILVA DE BARROS</ns0:nomeProf>
# <ns0:conselho>06</ns0:conselho>
# <ns0:numeroConselhoProfissional>160746</ns0:numeroConselhoProfissional>
# <ns0:UF>35</ns0:UF>
# <ns0:CBOS>225125</ns0:CBOS>
# </ns0:equipeSadt>
# </ns0:procedimentoExecutado>
# </ns0:procedimentosExecutados>
# <ns0:observacao>EXAME</ns0:observacao>
# <ns0:valorTotal>
# <ns0:valorProcedimentos>30.00</ns0:valorProcedimentos>
# <ns0:valorDiarias>0.00</ns0:valorDiarias>
# <ns0:valorTaxasAlugueis>0.00</ns0:valorTaxasAlugueis>
# <ns0:valorMateriais>0.00</ns0:valorMateriais>
# <ns0:valorMedicamentos>0.00</ns0:valorMedicamentos>
# <ns0:valorOPME>0.00</ns0:valorOPME>
# <ns0:valorGasesMedicinais>0.00</ns0:valorGasesMedicinais>
# <ns0:valorTotalGeral>30.00</ns0:valorTotalGeral>
# </ns0:valorTotal>
# </ns0:guiaSP-SADT>
# <ns0:guiaSP-SADT>
# <ns0:cabecalhoGuia>
# <ns0:registroANS>385255</ns0:registroANS>
# <ns0:numeroGuiaPrestador>528492</ns0:numeroGuiaPrestador>
# <ns0:guiaPrincipal>528492</ns0:guiaPrincipal>
# </ns0:cabecalhoGuia>
# <ns0:dadosBeneficiario>
# <ns0:numeroCarteira>1706691</ns0:numeroCarteira>
# <ns0:atendimentoRN>N</ns0:atendimentoRN>
# <ns0:nomeBeneficiario>CLEIDE DE OLIVEIRA ROCHA</ns0:nomeBeneficiario>
# <ns0:numeroCNS>0</ns0:numeroCNS>
# </ns0:dadosBeneficiario>
# <ns0:dadosSolicitante>
# <ns0:contratadoSolicitante>
# <ns0:codigoPrestadorNaOperadora>3733</ns0:codigoPrestadorNaOperadora>
# <ns0:nomeContratado>CENTRO CLINICO DE DIAGNOSTICOS POR IMAGEM BARTIRA LTDA EPP</ns0:nomeContratado>
# </ns0:contratadoSolicitante>
# <ns0:profissionalSolicitante>
# <ns0:nomeProfissional>THALINE BERTOLDO</ns0:nomeProfissional>
# <ns0:conselhoProfissional>06</ns0:conselhoProfissional>
# <ns0:numeroConselhoProfissional>115718</ns0:numeroConselhoProfissional>
# <ns0:UF>35</ns0:UF>
# <ns0:CBOS>225125</ns0:CBOS>
# </ns0:profissionalSolicitante>
# </ns0:dadosSolicitante>
# <ns0:dadosSolicitacao>
# <ns0:dataSolicitacao>2023-05-11</ns0:dataSolicitacao>
# <ns0:caraterAtendimento>1</ns0:caraterAtendimento>
# </ns0:dadosSolicitacao>
# <ns0:dadosExecutante>
# <ns0:contratadoExecutante>
# <ns0:cnpjContratado>17642803000142</ns0:cnpjContratado>
# <ns0:nomeContratado>UNIHOSP SAUDE S A</ns0:nomeContratado>
# </ns0:contratadoExecutante>
# <ns0:CNES>0000000</ns0:CNES>
# </ns0:dadosExecutante>
# <ns0:dadosAtendimento>
# <ns0:tipoAtendimento>03</ns0:tipoAtendimento>
# <ns0:indicacaoAcidente>9</ns0:indicacaoAcidente>
# <ns0:tipoConsulta>4</ns0:tipoConsulta>
# </ns0:dadosAtendimento>
# <ns0:procedimentosExecutados>
# <ns0:procedimentoExecutado>
# <ns0:dataExecucao>2023-05-11</ns0:dataExecucao>
# <ns0:horaInicial>08:15:00</ns0:horaInicial>
# <ns0:horaFinal>08:15:00</ns0:horaFinal>
# <ns0:procedimento>
# <ns0:codigoTabela>22</ns0:codigoTabela>
# <ns0:codigoProcedimento>20103506</ns0:codigoProcedimento>
# <ns0:descricaoProcedimento>PATOLOGIA OSTEOMIOARTICULAR EM UM SEGMENTO DA COLUNA</ns0:descricaoProcedimento>
# </ns0:procedimento>
# <ns0:quantidadeExecutada>1</ns0:quantidadeExecutada>
# <ns0:reducaoAcrescimo>1.00</ns0:reducaoAcrescimo>
# <ns0:valorUnitario>15.00</ns0:valorUnitario>
# <ns0:valorTotal>15.00</ns0:valorTotal>
# <ns0:equipeSadt>
# <ns0:grauPart>01</ns0:grauPart>
# <ns0:codProfissional>
# <ns0:codigoPrestadorNaOperadora>01</ns0:codigoPrestadorNaOperadora>
# </ns0:codProfissional>
# <ns0:nomeProf>THALINE BERTOLDO</ns0:nomeProf>
# <ns0:conselho>06</ns0:conselho>
# <ns0:numeroConselhoProfissional>115718</ns0:numeroConselhoProfissional>
# <ns0:UF>35</ns0:UF>
# <ns0:CBOS>225125</ns0:CBOS>
# </ns0:equipeSadt>
# </ns0:procedimentoExecutado>
# </ns0:procedimentosExecutados>
# <ns0:observacao>EXAME</ns0:observacao>
# <ns0:valorTotal>
# <ns0:valorProcedimentos>15.00</ns0:valorProcedimentos>
# <ns0:valorDiarias>0.00</ns0:valorDiarias>
# <ns0:valorTaxasAlugueis>0.00</ns0:valorTaxasAlugueis>
# <ns0:valorMateriais>0.00</ns0:valorMateriais>
# <ns0:valorMedicamentos>0.00</ns0:valorMedicamentos>
# <ns0:valorOPME>0.00</ns0:valorOPME>
# <ns0:valorGasesMedicinais>0.00</ns0:valorGasesMedicinais>
# <ns0:valorTotalGeral>15.00</ns0:valorTotalGeral>
# </ns0:valorTotal>
# </ns0:guiaSP-SADT>
# <ns0:guiaSP-SADT>
# <ns0:cabecalhoGuia>
# <ns0:registroANS>385255</ns0:registroANS>
# <ns0:numeroGuiaPrestador>528493</ns0:numeroGuiaPrestador>
# <ns0:guiaPrincipal>528493</ns0:guiaPrincipal>
# </ns0:cabecalhoGuia>
# <ns0:dadosBeneficiario>
# <ns0:numeroCarteira>1706691</ns0:numeroCarteira>
# <ns0:atendimentoRN>N</ns0:atendimentoRN>
# <ns0:nomeBeneficiario>CLEIDE DE OLIVEIRA ROCHA</ns0:nomeBeneficiario>
# <ns0:numeroCNS>0</ns0:numeroCNS>
# </ns0:dadosBeneficiario>
# <ns0:dadosSolicitante>
# <ns0:contratadoSolicitante>
# <ns0:codigoPrestadorNaOperadora>3733</ns0:codigoPrestadorNaOperadora>
# <ns0:nomeContratado>CENTRO CLINICO DE DIAGNOSTICOS POR IMAGEM BARTIRA LTDA EPP</ns0:nomeContratado>
# </ns0:contratadoSolicitante>
# <ns0:profissionalSolicitante>
# <ns0:nomeProfissional>MIRNA DA SILVA DE BARROS</ns0:nomeProfissional>
# <ns0:conselhoProfissional>06</ns0:conselhoProfissional>
# <ns0:numeroConselhoProfissional>160746</ns0:numeroConselhoProfissional>
# <ns0:UF>35</ns0:UF>
# <ns0:CBOS>225125</ns0:CBOS>
# </ns0:profissionalSolicitante>
# </ns0:dadosSolicitante>
# <ns0:dadosSolicitacao>
# <ns0:dataSolicitacao>2023-05-11</ns0:dataSolicitacao>
# <ns0:caraterAtendimento>1</ns0:caraterAtendimento>
# </ns0:dadosSolicitacao>
# <ns0:dadosExecutante>
# <ns0:contratadoExecutante>
# <ns0:cnpjContratado>17642803000142</ns0:cnpjContratado>
# <ns0:nomeContratado>UNIHOSP SAUDE S A</ns0:nomeContratado>
# </ns0:contratadoExecutante>
# <ns0:CNES>0000000</ns0:CNES>
# </ns0:dadosExecutante>
# <ns0:dadosAtendimento>
# <ns0:tipoAtendimento>03</ns0:tipoAtendimento>
# <ns0:indicacaoAcidente>9</ns0:indicacaoAcidente>
# <ns0:tipoConsulta>4</ns0:tipoConsulta>
# </ns0:dadosAtendimento>
# <ns0:procedimentosExecutados>
# <ns0:procedimentoExecutado>
# <ns0:dataExecucao>2023-05-11</ns0:dataExecucao>
# <ns0:horaInicial>08:15:00</ns0:horaInicial>
# <ns0:horaFinal>08:15:00</ns0:horaFinal>
# <ns0:procedimento>
# <ns0:codigoTabela>22</ns0:codigoTabela>
# <ns0:codigoProcedimento>31601014</ns0:codigoProcedimento>
# <ns0:descricaoProcedimento>ACUPUNTURA POR SESSAO</ns0:descricaoProcedimento>
# </ns0:procedimento>
# <ns0:quantidadeExecutada>1</ns0:quantidadeExecutada>
# <ns0:reducaoAcrescimo>1.00</ns0:reducaoAcrescimo>
# <ns0:valorUnitario>30.00</ns0:valorUnitario>
# <ns0:valorTotal>30.00</ns0:valorTotal>
# <ns0:equipeSadt>
# <ns0:grauPart>01</ns0:grauPart>
# <ns0:codProfissional>
# <ns0:codigoPrestadorNaOperadora>01</ns0:codigoPrestadorNaOperadora>
# </ns0:codProfissional>
# <ns0:nomeProf>MIRNA DA SILVA DE BARROS</ns0:nomeProf>
# <ns0:conselho>06</ns0:conselho>
# <ns0:numeroConselhoProfissional
ns0:tipoAtendimento>
# <ns0:indicacaoAcidente>9</ns0:indicacaoAcidente>
# <ns0:tipoConsulta>4</ns0:tipoConsulta>
# </ns0:dadosAtendimento>
# <ns0:procedimentosExecutados>
# <ns0:procedimentoExecutado>
# <ns0:dataExecucao>2023-05-12</ns0:dataExecucao>
# <ns0:horaInicial>13:08:00</ns0:horaInicial>
# <ns0:horaFinal>13:08:00</ns0:horaFinal>
# <ns0:procedimento>
# <ns0:codigoTabela>22</ns0:codigoTabela>
# <ns0:codigoProcedimento>31601014</ns0:codigoProcedimento>
# <ns0:descricaoProcedimento>ACUPUNTURA POR SESSAO</ns0:descricaoProcedimento>
# </ns0:procedimento>
# <ns0:quantidadeExecutada>1</ns0:quantidadeExecutada>
# <ns0:reducaoAcrescimo>1.00</ns0:reducaoAcrescimo>
# <ns0:valorUnitario>30.00</ns0:valorUnitario>
# <ns0:valorTotal>30.00</ns0:valorTotal>
# <ns0:equipeSadt>
# <ns0:grauPart>01</ns0:grauPart>
# <ns0:codProfissional>
# <ns0:codigoPrestadorNaOperadora>01</ns0:codigoPrestadorNaOperadora>
# </ns0:codProfissional>
# <ns0:nomeProf>MIRNA DA SILVA DE BARROS</ns0:nomeProf>
# <ns0:conselho>06</ns0:conselho>
# <ns0:numeroConselhoProfissional>160746</ns0:numeroConselhoProfissional>
# <ns0:UF>35</ns0:UF>
# <ns0:CBOS>225125</ns0:CBOS>
# </ns0:equipeSadt>
# </ns0:procedimentoExecutado>
# </ns0:procedimentosExecutados>
# <ns0:observacao>EXAME</ns0:observacao>
# <ns0:valorTotal>
# <ns0:valorProcedimentos>30.00</ns0:valorProcedimentos>
# <ns0:valorDiarias>0.00</ns0:valorDiarias>
# <ns0:valorTaxasAlugueis>0.00</ns0:valorTaxasAlugueis>
# <ns0:valorMateriais>0.00</ns0:valorMateriais>
# <ns0:valorMedicamentos>0.00</ns0:valorMedicamentos>
# <ns0:valorOPME>0.00</ns0:valorOPME>
# <ns0:valorGasesMedicinais>0.00</ns0:valorGasesMedicinais>
# <ns0:valorTotalGeral>30.00</ns0:valorTotalGeral>
# </ns0:valorTotal>
# </ns0:guiaSP-SADT>
# <ns0:guiaSP-SADT>
# <ns0:cabecalhoGuia>
# <ns0:registroANS>385255</ns0:registroANS>
# <ns0:numeroGuiaPrestador>529360</ns0:numeroGuiaPrestador>
# <ns0:guiaPrincipal>529360</ns0:guiaPrincipal>
# </ns0:cabecalhoGuia>
# <ns0:dadosBeneficiario>
# <ns0:numeroCarteira>0275514</ns0:numeroCarteira>
# <ns0:atendimentoRN>N</ns0:atendimentoRN>
# <ns0:nomeBeneficiario>MARLI APARECIDA CAPRARI</ns0:nomeBeneficiario>
# <ns0:numeroCNS>0</ns0:numeroCNS>
# </ns0:dadosBeneficiario>
# <ns0:dadosSolicitante>
# <ns0:contratadoSolicitante>
# <ns0:codigoPrestadorNaOperadora>3733</ns0:codigoPrestadorNaOperadora>
# <ns0:nomeContratado>CENTRO CLINICO DE DIAGNOSTICOS POR IMAGEM BARTIRA LTDA EPP</ns0:nomeContratado>
# </ns0:contratadoSolicitante>
# <ns0:profissionalSolicitante>
# <ns0:nomeProfissional>CLAUDIA REGINA MOSQUETTI</ns0:nomeProfissional>
# <ns0:conselhoProfissional>06</ns0:conselhoProfissional>
# <ns0:numeroConselhoProfissional>144931</ns0:numeroConselhoProfissional>
# <ns0:UF>35</ns0:UF>
# <ns0:CBOS>225125</ns0:CBOS>
# </ns0:profissionalSolicitante>
# </ns0:dadosSolicitante>
# <ns0:dadosSolicitacao>
# <ns0:dataSolicitacao>2023-05-12</ns0:dataSolicitacao>
# <ns0:caraterAtendimento>1</ns0:caraterAtendimento>
# </ns0:dadosSolicitacao>
# <ns0:dadosExecutante>
# <ns0:contratadoExecutante>
# <ns0:cnpjContratado>17642803000142</ns0:cnpjContratado>
# <ns0:nomeContratado>UNIHOSP SAUDE S A</ns0:nomeContratado>
# </ns0:contratadoExecutante>
# <ns0:CNES>0000000</ns0:CNES>
# </ns0:dadosExecutante>
# <ns0:dadosAtendimento>
# <ns0:tipoAtendimento>02</ns0:tipoAtendimento>
# <ns0:indicacaoAcidente>9</ns0:indicacaoAcidente>
# <ns0:tipoConsulta>4</ns0:tipoConsulta>
# </ns0:dadosAtendimento>
# <ns0:procedimentosExecutados>
# <ns0:procedimentoExecutado>
# <ns0:dataExecucao>2023-05-12</ns0:dataExecucao>
# <ns0:horaInicial>12:32:00</ns0:horaInicial>
# <ns0:horaFinal>12:32:00</ns0:horaFinal>
# <ns0:procedimento>
# <ns0:codigoTabela>22</ns0:codigoTabela>
# <ns0:codigoProcedimento>30101093</ns0:codigoProcedimento>
# <ns0:descricaoProcedimento>CALOSIDADE E OU MAL PERFURANTE: DESBASTAMENTOS</ns0:descricaoProcedimento>
# </ns0:procedimento>
# <ns0:quantidadeExecutada>4</ns0:quantidadeExecutada>
# <ns0:reducaoAcrescimo>1.00</ns0:reducaoAcrescimo>
# <ns0:valorUnitario>0.00</ns0:valorUnitario>
# <ns0:valorTotal>0.00</ns0:valorTotal>
# <ns0:equipeSadt>
# <ns0:grauPart>01</ns0:grauPart>
# <ns0:codProfissional>
# <ns0:codigoPrestadorNaOperadora>01</ns0:codigoPrestadorNaOperadora>
# </ns0:codProfissional>
# <ns0:nomeProf>CLAUDIA REGINA MOSQUETTI</ns0:nomeProf>
# <ns0:conselho>06</ns0:conselho>
# <ns0:numeroConselhoProfissional>144931</ns0:numeroConselhoProfissional>
# <ns0:UF>35</ns0:UF>
# <ns0:CBOS>225125</ns0:CBOS>
# </ns0:equipeSadt>
# </ns0:procedimentoExecutado>
# </ns0:procedimentosExecutados>
# <ns0:observacao>EXAME</ns0:observacao>
# <ns0:valorTotal>
# <ns0:valorProcedimentos>0.00</ns0:valorProcedimentos>
# <ns0:valorDiarias>0.00</ns0:valorDiarias>
# <ns0:valorTaxasAlugueis>0.00</ns0:valorTaxasAlugueis>
# <ns0:valorMateriais>0.00</ns0:valorMateriais>
# <ns0:valorMedicamentos>0.00</ns0:valorMedicamentos>
# <ns0:valorOPME>0.00</ns0:valorOPME>
# <ns0:valorGasesMedicinais>0.00</ns0:valorGasesMedicinais>
# <ns0:valorTotalGeral>0.00</ns0:valorTotalGeral>
# </ns0:valorTotal>
# </ns0:guiaSP-SADT>
# <ns0:guiaSP-SADT>
# <ns0:cabecalhoGuia>
# <ns0:registroANS>385255</ns0:registroANS>
# <ns0:numeroGuiaPrestador>529447</ns0:numeroGuiaPrestador>
# <ns0:guiaPrincipal>529447</ns0:guiaPrincipal>
# </ns0:cabecalhoGuia>
# <ns0:dadosBeneficiario>
# <ns0:numeroCarteira>0283738</ns0:numeroCarteira>
# <ns0:atendimentoRN>N</ns0:atendimentoRN>
# <ns0:nomeBeneficiario>HATSUO HIDAKA</ns0:nomeBeneficiario>
# <ns0:numeroCNS>0</ns0:numeroCNS>
# </ns0:dadosBeneficiario>
# <ns0:dadosSolicitante>
# <ns0:contratadoSolicitante>
# <ns0:codigoPrestadorNaOperadora>3733</ns0:codigoPrestadorNaOperadora>
# <ns0:nomeContratado>CENTRO CLINICO DE DIAGNOSTICOS POR IMAGEM BARTIRA LTDA EPP</ns0:nomeContratado>
# </ns0:contratadoSolicitante>
# <ns0:profissionalSolicitante>
# <ns0:nomeProfissional>THALINE BERTOLDO</ns0:nomeProfissional>
# <ns0:conselhoProfissional>06</ns0:conselhoProfissional>
# <ns0:numeroConselhoProfissional>115718</ns0:numeroConselhoProfissional>
# <ns0:UF>35</ns0:UF>
# <ns0:CBOS>225125</ns0:CBOS>
# </ns0:profissionalSolicitante>
# </ns0:dadosSolicitante>
# <ns0:dadosSolicitacao>
# <ns0:dataSolicitacao>2023-05-12</ns0:dataSolicitacao>
# <ns0:caraterAtendimento>1</ns0:caraterAtendimento>
# </ns0:dadosSolicitacao>
# <ns0:dadosExecutante>
# <ns0:contratadoExecutante>
# <ns0:cnpjContratado>17642803000142</ns0:cnpjContratado>
# <ns0:nomeContratado>UNIHOSP SAUDE S A</ns0:nomeContratado>
# </ns0:contratadoExecutante>
# <ns0:CNES>0000000</ns0:CNES>
# </ns0:dadosExecutante>
# <ns0:dadosAtendimento>
# <ns0:tipoAtendimento>03</ns0:tipoAtendimento>
# <ns0:indicacaoAcidente>9</ns0:indicacaoAcidente>
# <ns0:tipoConsulta>4</ns0:tipoConsulta>
# </ns0:dadosAtendimento>
# <ns0:procedimentosExecutados>
# <ns0:procedimentoExecutado>
# <ns0:dataExecucao>2023-05-12</ns0:dataExecucao>
# <ns0:horaInicial>07:04:00</ns0:horaInicial>
# <ns0:horaFinal>07:04:00</ns0:horaFinal>
# <ns0:procedimento>
# <ns0:codigoTabela>22</ns0:codigoTabela>
# <ns0:codigoProcedimento>20103492</ns0:codigoProcedimento>
# <ns0:descricaoProcedimento>PATOLOGIA OSTEOMIOARTICULAR EM DOIS OU MAIS MEMBROS</ns0:descricaoProcedimento>
# </ns0:procedimento>
# <ns0:quantidadeExecutada>1</ns0:quantidadeExecutada>
# <ns0:reducaoAcrescimo>1.00</ns0:reducaoAcrescimo>
# <ns0:valorUnitario>15.00</ns0:valorUnitario>
# <ns0:valorTotal>15.00</ns0:valorTotal>
# <ns0:equipeSadt>
# <ns0:grauPart>01</ns0:grauPart>
# <ns0:codProfissional>
# <ns0:codigoPrestadorNaOperadora>01</ns0:codigoPrestadorNaOperadora>
# </ns0:codProfissional>
# <ns0:nomeProf>THALINE BERTOLDO</ns0:nomeProf>
# <ns0:conselho>06</ns0:conselho>
# <ns0:numeroConselhoProfissional>115718</ns0:numeroConselhoProfissional>
# <ns0:UF>35</ns0:UF>
# <ns0:CBOS>225125</ns0:CBOS>
# </ns0:equipeSadt>
# </ns0:procedimentoExecutado>
# </ns0:procedimentosExecutados>
# <ns0:observacao>EXAME</ns0:observacao>
# <ns0:valorTotal>
# <ns0:valorProcedimentos>15.00</ns0:valorProcedimentos>
# <ns0:valorDiarias>0.00</ns0:valorDiarias>
# <ns0:valorTaxasAlugueis>0.00</ns0:valorTaxasAlugueis>
# <ns0:valorMateriais>0.00</ns0:valorMateriais>
# <ns0:valorMedicamentos>0.00</ns0:valorMedicamentos>
# <ns0:valorOPME>0.00</ns0:valorOPME>
# <ns0:valorGasesMedicinais>0.00</ns0:valorGasesMedicinais>
# <ns0:valorTotalGeral>15.00</ns0:valorTotalGeral>
# </ns0:valorTotal>
# </ns0:guiaSP-SADT>
# <ns0:guiaSP-SADT>
# <ns0:cabecalhoGuia>
# <ns0:registroANS>385255</ns0:registroANS>
# <ns0:numeroGuiaPrestador>529448</ns0:numeroGuiaPrestador>
# <ns0:guiaPrincipal>529448</ns0:guiaPrincipal>
# </ns0:cabecalhoGuia>
# <ns0:dadosBeneficiario>
# <ns0:numeroCarteira>0283738</ns0:numeroCarteira>
# <ns0:atendimentoRN>N</ns0:atendimentoRN>
# <ns0:nomeBeneficiario>HATSUO HIDAKA</ns0:nomeBeneficiario>
# <ns0:numeroCNS>0</ns0:numeroCNS>
# </ns0:dadosBeneficiario>
# <ns0:dadosSolicitante>
# <ns0:contratadoSolicitante>
# <ns0:codigoPrestadorNaOperadora>3733</ns0:codigoPrestadorNaOperadora>
# <ns0:nomeContratado>CENTRO CLINICO DE DIAGNOSTICOS POR IMAGEM BARTIRA LTDA EPP</ns0:nomeContratado>
# </ns0:contratadoSolicitante>
# <ns0:profissionalSolicitante>
# <ns0:nomeProfissional>MIRNA DA SILVA DE BARROS</ns0:nomeProfissional>
# <ns0:conselhoProfissional>06</ns0:conselhoProfissional>
# <ns0:numeroConselhoProfissional>160746</ns0:numeroConselhoProfissional>
# <ns0:UF>35</ns0:UF>
# <ns0:CBOS>225125</ns0:CBOS>
# </ns0:profissionalSolicitante>
# </ns0:dadosSolicitante>
# <ns0:dadosSolicitacao>
# <ns0:dataSolicitacao>2023-05-12</ns0:dataSolicitacao>
# <ns0:caraterAtendimento>1</ns0:caraterAtendimento>
# </ns0:dadosSolicitacao>
# <ns0:dadosExecutante>
# <ns0:contratadoExecutante>
# <ns0:cnpjContratado>17642803000142</ns0:cnpjContratado>
# <ns0:nomeContratado>UNIHOSP SAUDE S A</ns0:nomeContratado>
# </ns0:contratadoExecutante>
# <ns0:CNES>0000000</ns0:CNES>
# </ns0:dadosExecutante>
# <ns0:dadosAtendimento>
# <ns0:tipoAtendimento>03</ns0:tipoAtendimento>
# <ns0:indicacaoAcidente>9</ns0:indicacaoAcidente>
# <ns0:tipoConsulta>4</ns0:tipoConsulta>
# </ns0:dadosAtendimento>
# <ns0:procedimentosExecutados>
# <ns0:procedimentoExecutado>
# <ns0:dataExecucao>2023-05-12</ns0:dataExecucao>
# <ns0:horaInicial>07:04:00</ns0:horaInicial>
# <ns0:horaFinal>07:04:00</ns0:horaFinal>
# <ns0:procedimento>
# <ns0:codigoTabela>22</ns0:codigoTabela>
# <ns0:codigoProcedimento>31601014</ns0:codigoProcedimento>
# <ns0:descricaoProcedimento>ACUPUNTURA POR SESSAO</ns0:descricaoProcedimento>
# </ns0:procedimento>
# <ns0:quantidadeExecutada>1</ns0:quantidadeExecutada>
# <ns0:reducaoAcrescimo>1.00</ns0:reducaoAcrescimo>
# <ns0:valorUnitario>30.00</ns0:valorUnitario>
# <ns0:valorTotal>30.00</ns0:valorTotal>
# <ns0:equipeSadt>
# <ns0:grauPart>01</ns0:grauPart>
# <ns0:codProfissional>
# <ns0:codigoPrestadorNaOperadora>01</ns0:codigoPrestadorNaOperadora>
# </ns0:codProfissional>
# <ns0:nomeProf>MIRNA DA SILVA DE BARROS</ns0:nomeProf>
# <ns0:conselho>06</ns0:conselho>
# <ns0:numeroConselhoProfissional>160746</ns0:numeroConselhoProfissional>
# <ns0:UF>35</ns0:UF>
# <ns0:CBOS>225125</ns0:CBOS>
# </ns0:equipeSadt>
# </ns0:procedimentoExecutado>
# </ns0:procedimentosExecutados>
# <ns0:observacao>EXAME</ns0:observacao>
# <ns0:valorTotal>
# <ns0:valorProcedimentos>30.00</ns0:valorProcedimentos>
# <ns0:valorDiarias>0.00</ns0:valorDiarias>
# <ns0:valorTaxasAlugueis>0.00</ns0:valorTaxasAlugueis>
# <ns0:valorMateriais>0.00</ns0:valorMateriais>
# <ns0:valorMedicamentos>0.00</ns0:valorMedicamentos>
# <ns0:valorOPME>0.00</ns0:valorOPME>
# <ns0:valorGasesMedicinais>0.00</ns0:valorGasesMedicinais>
# <ns0:valorTotalGeral>30.00</ns0:valorTotalGeral>
# </ns0:valorTotal>
# </ns0:guiaSP-SADT>
# <ns0:guiaSP-SADT>
# <ns0:cabecalhoGuia>
# <ns0:registroANS>385255</ns0:registroANS>
# <ns0:numeroGuiaPrestador>529495</ns0:numeroGuiaPrestador>
# <ns0:guiaPrincipal>529495</ns0:guiaPrincipal>
# </ns0:cabecalhoGuia>
# <ns0:dadosBeneficiario>
# <ns0:numeroCarteira>0318299</ns0:numeroCarteira>
# <ns0:atendimentoRN>N</ns0:atendimentoRN>
# <ns0:nomeBeneficiario>CLAUDINEI NATAL DE OLIVEIRA PRETO</ns0:nomeBeneficiario>
# <ns0:numeroCNS>0</ns0:numeroCNS>
# </ns0:dadosBeneficiario>
# <ns0:dadosSolicitante>
# <ns0:contratadoSolicitante>
# <ns0:codigoPrestadorNaOperadora>3733</ns0:codigoPrestadorNaOperadora>
# <ns0:nomeContratado>CENTRO CLINICO DE DIAGNOSTICOS POR IMAGEM BARTIRA LTDA EPP</ns0:nomeContratado>
# </ns0:contratadoSolicitante>
# <ns0:profissionalSolicitante>
# <ns0:nomeProfissional>THALINE BERTOLDO</ns0:nomeProfissional>
# <ns0:conselhoProfissional>06</ns0:conselhoProfissional>
# <ns0:numeroConselhoProfissional>115718</ns0:numeroConselhoProfissional>
# <ns0:UF>35</ns0:UF>
# <ns0:CBOS>225125</ns0:CBOS>
# </ns0:profissionalSolicitante>
# </ns0:dadosSolicitante>
# <ns0:dadosSolicitacao>
# <ns0:dataSolicitacao>2023-05-12</ns0:dataSolicitacao>
# <ns0:caraterAtendimento>1</ns0:caraterAtendimento>
# </ns0:dadosSolicitacao>
# <ns0:dadosExecutante>
# <ns0:contratadoExecutante>
# <ns0:cnpjContratado>17642803000142</ns0:cnpjContratado>
# <ns0:nomeContratado>UNIHOSP SAUDE S A</ns0:nomeContratado>
# </ns0:contratadoExecutante>
# <ns0:CNES>0000000</ns0:CNES>
# </ns0:dadosExecutante>
# <ns0:dadosAtendimento>
# <ns0:tipoAtendimento>03</ns0:tipoAtendimento>
# <ns0:indicacaoAcidente>9</ns0:indicacaoAcidente>
# <ns0:tipoConsulta>4</ns0:tipoConsulta>
# </ns0:dadosAtendimento>
# <ns0:procedimentosExecutados>
# <ns0:procedimentoExecutado>
# <ns0:dataExecucao>2023-05-12</ns0:dataExecucao>
# <ns0:horaInicial>15:04:00</ns0:horaInicial>
# <ns0:horaFinal>15:04:00</ns0:horaFinal>
# <ns0:procedimento>
# <ns0:codigoTabela>22</ns0:codigoTabela>
# <ns0:codigoProcedimento>20103506</ns0:codigoProcedimento>
# <ns0:descricaoProcedimento>PATOLOGIA OSTEOMIOARTICULAR EM UM SEGMENTO DA COLUNA</ns0:descricaoProcedimento>
# </ns0:procedimento>
# <ns0:quantidadeExecutada>1</ns0:quantidadeExecutada>
# <ns0:reducaoAcrescimo>1.00</ns0:reducaoAcrescimo>
# <ns0:valorUnitario>15.00</ns0:valorUnitario>
# <ns0:valorTotal>15.00</ns0:valorTotal>
# <ns0:equipeSadt>
# <ns0:grauPart>01</ns0:grauPart>
# <ns0:codProfissional>
# <ns0:codigoPrestadorNaOperadora>01</ns0:codigoPrestadorNaOperadora>
# </ns0:codProfissional>
# <ns0:nomeProf>THALINE BERTOLDO</ns0:nomeProf>
# <ns0:conselho>06</ns0:conselho>
# <ns0:numeroConselhoProfissional>115718</ns0:numeroConselhoProfissional>
# <ns0:UF>35</ns0:UF>
# <ns0:CBOS>225125</ns0:CBOS>
# </ns0:equipeSadt>
# </ns0:procedimentoExecutado>
# </ns0:procedimentosExecutados>
# <ns0:observacao>EXAME</ns0:observacao>
# <ns0:valorTotal>
# <ns0:valorProcedimentos>15.00</ns0:valorProcedimentos>
# <ns0:valorDiarias>0.00</ns0:valorDiarias>
# <ns0:valorTaxasAlugueis>0.00</ns0:valorTaxasAlugueis>
# <ns0:valorMateriais>0.00</ns0:valorMateriais>
# <ns0:valorMedicamentos>0.00</ns0:valorMedicamentos>
# <ns0:valorOPME>0.00</ns0:valorOPME>
# <ns0:valorGasesMedicinais>0.00</ns0:valorGasesMedicinais>
# <ns0:valorTotalGeral>15.00</ns0:valorTotalGeral>
# </ns0:valorTotal>
# </ns0:guiaSP-SADT>
# </ns0:guiasTISS>
# </ns0:loteGuias>
# </ns0:prestadorParaOperadora>
# <ns0:epilogo>
# <ns0:hash>26BAEB3B5DE3A0E7AC24D5A014158638</ns0:hash>
# </ns0:epilogo>
# </ns0:mensagemTISS>
